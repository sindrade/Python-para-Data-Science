# %% [markdown]
# ## Coleta e amostragem de dados

# %%
nome = input("Digite seu nome: ")
print(f"\nOlá, {nome}")
# Out:
# Digite seu nome: João Paulo
#
# Olá, João Paulo

# %%
nome2 = input("Digite seu nome:")
idade = input("Digite sua idade:")
print("Olá, {}, você tem {} anos.".format(nome2, idade))
# Out:
# Digite seu nome:Fátima
# Digite sua idade:23
# Olá, Fátima, você tem 23 anos.

# %%
nome3 = input("Digite seu nome: ")
idade3 = input("Digite sua idade: ")
altura = input("Qual a sua altura: ").replace(",",".")
print("Olá, {}, você tem {} anos e mede {} metros!".format(nome3, idade3, float(altura)))
# Out:
# Digite seu nome: Solange Farias
# Digite sua idade: 26
# Qual a sua altura: 1,65
# Olá, Solange Farias, você tem 26 anos e mede 1.65 metros!

# %% [markdown]
# ## Calculadora com operadores

# %%
print("Vamos somar números!")
numero1 = float(input("Digite o primeiro número: "))
numero2 = float(input("Agora digite o segundo número: "))
print("\nA soma dos dois valores é {}".format(numero1 + numero2))
# Out:
# Vamos somar números!
# Digite o primeiro número: 5
# Agora digite o segundo número: 3
#
# A soma dos dois valores é 8.0

# %%
numero01 = float(input("Digite o primeiro número:"))
numero02 = float(input("Digite o segundo número: "))
numero03 = float(input("Digite o terceiro número: "))
print("\n A soma dos três valores é {}".format(numero01 + numero02 + numero03))
# Out:
# Digite o primeiro número:10
# Digite o segundo número: 3
# Digite o terceiro número: 5
#
#  A soma dos três valores é 18.0

# %%
sub01 = float(input("Digite o primeiro número:"))
sub02 = float(input("Digite o segundo número: "))
print("\n O resultado da subtração entre os número é {}".format(sub01 - sub02))
# Out:
# Digite o primeiro número:50
# Digite o segundo número: 32
#
#  O resultado da subtração entre os número é 18.0

# %%
mult01 = float(input("Digite um número:"))
mult02 = float(input("Digite o segundo número:"))
print("\n A multiplicação entre os dois números é igual a {}".format(mult01*mult02))
# Out:
# Digite um número:50
# Digite o segundo número:2
#
#  A multiplicação entre os dois números é igual a 100.0

# %%
div01 = float(input("Informe um número:"))
div02 = float(input("Informe outro número diferente de 0:"))
print("\n A divisão entre os dois números é igual a: {}".format(div01/div02))
# Out:
# Informe um número:50
# Informe outro número diferente de 0:2
#
#  A divisão entre os dois números é igual a: 25.0

# %%
operador = int(input("Digite um número operador:"))
potencia = int(input("Digite uma potência:"))
print("\n A exponeciação entre os dois valores é: {}".format(operador**potencia))
# Out:
# Digite um número operador:2
# Digite uma potência:3
#
#  A exponeciação entre os dois valores é: 8

# %%
numerador = int(input("Digite um numerador:"))
denominador = int(input("Digite um denominador Diferente de 0: "))
print("A divisão inteira entre os dois valores é: {}".format(numerador // denominador))
# Out:
# Digite um numerador:5
# Digite um denominador Diferente de 0: 2
# A divisão inteira entre os dois valores é: 2

# %%
numerador1 = float(input("Digite um número"))
denonimador1 = float(input("Digite um número denominador"))
print("O resto da divisão entre os dois número é: {}".format(numerador1 % denominador))
# Out:
# Digite um número5
# Digite um número denominador2
# O resto da divisão entre os dois número é: 1.0

# %%
print("Vamos calcular a média do aluno!\n")
nota1 = float(input("Digite a primeira nota"))
nota2 = float(input("Digite a segunda nota"))
nota3 = float(input("Digite a terceira nota"))
print("\nA média do aluno é: {}".format((nota1+nota2+nota3)/3))
# Out:
# Vamos calcular a média do aluno!
#
# Digite a primeira nota10
# Digite a segunda nota5
# Digite a terceira nota10
#
# A média do aluno é: 8.333333333333334

# %%
print("A média ponderada entre os números é: {}".format((5*1 + 12*2 + 20*3 + 15*4) / (1+2+3+4) ))
# Out:
# A média ponderada entre os números é: 14.9

# %% [markdown]
# ## Editando textos

# %%
frase = "Olá mundo!"
print(frase)
# Out:
# Olá mundo!

# %%
frase1 = input("Digite uma frase: ")
print(frase1)
# Out:
# Digite uma frase: Esse é um código Python!
# Esse é um código Python!

# %%
fraseUpper = input("Digite uma frase: ")
print(fraseUpper.upper())
# Out:
# Digite uma frase: Olá pessoal, tudo bem com vocês?
# OLÁ PESSOAL, TUDO BEM COM VOCÊS?

# %%
fraseLower = input("Digite uma frase: ")
print(fraseLower.lower())
# Out:
# Digite uma frase: TUDO BEM COM VOCÊS?
# tudo bem com vocês?

# %%
fraseEs = "   Olá, galera! "
print(fraseEs.strip())
# Out:
# Olá, galera!

# %%
fraseEs1 = input("Digite uma frase: ").strip()
print(fraseEs1)
# Out:
# Digite uma frase:       Olá... tudo bem?
# Olá... tudo bem?

# %%
fraseEs2 = input("Digite uma frase: ").strip().lower()
print(fraseEs2)
# Out:
# Digite uma frase:         OLÁ, COMO VOCÊS ESTÃO?
# olá, como vocês estão?

# %%
fraseEs3 = input("Digite uma frase: ").replace("e", "f")
print(fraseEs3)
# Out:
# Digite uma frase: eu sou uma pessoa legal e estudiosa
# fu sou uma pfssoa lfgal f fstudiosa

# %%
fraseEs4 = input("Digite uma frase: ").replace("a", "@")
print(fraseEs4)
# Out:
# Digite uma frase: agora é a hora de ir pra casa
# @gor@ é @ hor@ de ir pr@ c@s@

# %%
fraseEs5 = input("Digite uma frase: ").replace("s", "$")
print(fraseEs5)
# Out:
# Digite uma frase: sábado será um dia de sol
# $ábado $erá um dia de $ol

# %% [markdown]
# ## Exercícios de estruturas Condicionais

# %%
#1) Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.
num1 = float(input("Informe um número: "))
num2 = float(input("Informe outro núemro: "))

if num1 > num2:
    print(f"O número maior é: {num1}")
else:
    print(f"O número maior é: {num2}")
# Out:
# Informe um número: 32
# Informe outro núemro: 63
# O número maior é: 63.0

# %%
# 2) Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve 
# um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

percentual = float(input("Qual o percentual de crescimento de produção da empresa? "))
if percentual > 0:
    print("\nHouve um crescimento na produção.")
else:
    print("\nHouve um descrescimento na produção.")
# Out:
# Qual o percentual de crescimento de produção da empresa? 35
#
# Houve um crescimento na produção.

# %%
# 3) Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.
vogais = ["a", "e", "i", "o", "u"]
letra = input("Digite uma letra: ").upper()
if letra in vogais:
    print(f'A letra "{letra}", que foi digitada, é uma vogal!')
else:
    print(f'A letra "{letra}", que foi digitada, é uma consoante!')
# Out:
# Digite uma letra: h
# A letra "H", que foi digitada, é uma consoante!

# %%
#4) Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e 
# exiba o valor mais alto e mais baixo entre esses três anos.
preco1 = 45001
preco2 = 45000
preco3 = 30000
if preco1 > preco2 > preco3:
    print(f"O preço mais alto é do ano 01: {preco1}")
elif preco2 > preco1 > preco3:
    print(f'O preço mais alto é do ano 02: {preco2}')
else:
    print(f'O preço mais alto é do ano 03: {preco3}')
    
if preco1 < preco2 < preco3:
    print(f'O preço mais baixo é do ano 01: {preco1}')
elif preco2 < preco1 < preco3:
    print(f'O preço mais baixo é do ano 02: {preco2}')
else:
    print(f'O preço mais baixo é do ano 03: {preco3}')
# Out:
# O preço mais alto é do ano 01: 45001
# O preço mais baixo é do ano 03: 30000

# %%
#5) Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.
produto1 = float(input("Qual o preço do produto 01: "))
produto2 = float(input("Qual o preço do produto 02: "))
produto3 = float(input("Qual o preço do produto 03: "))

if produto1 < produto2 < produto3:
    print(f"\nO produto mais barato é o de preço: {produto1}")
elif produto2 < produto1 < produto3:
    print(f"\nO produto mais barato é o de preço: {produto2}")
else:
    print(f"\nO produto mais barato é o de preço: {produto3}")
# Out:
# Qual o preço do produto 01: 100
# Qual o preço do produto 02: 500
# Qual o preço do produto 03: 50
#
# O produto mais barato é o de preço: 50.0

# %%
#6) Escreva um programa que leia três números e os exiba em ordem decrescente.
lista_num = []
num_lis1 = lista_num.append(int(input("Digite o 1º número: "))) 
num_lis2 = lista_num.append(int(input("Digite o 2º número: "))) 
num_lis3 = lista_num.append(int(input("Digite o 3º número: "))) 
lista_num.sort(reverse=True)
print("-----------")
print(lista_num)
# Out:
# Digite o 1º número: 32
# Digite o 2º número: 65
# Digite o 3º número: 99
# -----------
# [99, 65, 32]

# %%
#7) Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e 
# exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.
turno = input("Qual turno você estuda?").lower()
if turno == "manhã":
    print("Bom dia e bons estudos!")
elif turno == "tarde":
    print("Boa tarde e bons estudos!")
elif turno == "noite":
    print("Boa noite e bons estudos!")
else:
    print(f"Valor inválido: {turno}. Informe os perídos: manhã, tarde ou noite.")
# Out:
# Bom dia e bons estudos!

# %%
#8) Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.
numero = int(input("Insira um número: "))

if numero % 2 == 0:
    print(f"O número {numero} é par.")
else:
    print(f"O númerto {numero} é ímpar.")
# Out:
# O número 52 é par.

# %%
#9) Escreva um programa que peça um número à pessoa usuária e informe se ele é inteiro ou decimal.
# Coletamos os dados
num = float(input('Digite um número: '))

# Verificamos se o número é inteiro ou decimal através do resultado do módulo
if num % 1 == 0:
    print(f'O número {num} é inteiro.')
else:
    print(f'O número {num} é decimal.')
# Out:
# O número 30.6 é decimal.

# %%
#10) Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações 
# sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.
# Coletamos os números a serem operados e solicitamos a operação desejada pela pessoa usuária
num1 = float(input('Informe o primeiro número: '))
num2 = float(input('Informe o segundo número: '))
operacao = input('Informe a operação desejada (+, -, *, /): ')

# Verificamos o operador que foi selecionado e executa a operação matemática conforme a seleção
if operacao == '+':
    resultado = num1 + num2
elif operacao == '-':
    resultado = num1 - num2
elif operacao == '*':
    resultado = num1 * num2
elif operacao == '/':
    resultado = num1 / num2
else: # Especificamos um resultado caso a pessoa usuária não digite alguma das operações corretamente.
    print('Operação inválida, resultado da operação será 0')
    resultado = 0 

#  Fazemos as mesmas verificações das questões anteriores para fazer o relatório do cálculo entre números
if resultado % 1 == 0:
    print('O resultado é inteiro.')
else:
    print('O resultado é decimal.')

if resultado > 0:
    print('O resultado é positivo.')
elif resultado == 0:
    print('O resultado é neutro.')
else:
    print('O resultado é negativo.')

if resultado % 2 == 0:
    print('O resultado é par.')
else:
    print('O resultado é ímpar.')
# Out:
# O resultado é inteiro.
# O resultado é positivo.
# O resultado é par.

# %%
#11) Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um 
# triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
# Coletamos os lados de um triângulo
print('Coletaremos os lados de um triângulo.')
lado1 = float(input('Digite o comprimento do primeiro lado: '))
lado2 = float(input('Digite o comprimento do segundo lado: '))
lado3 = float(input('Digite o comprimento do terceiro lado: '))

# Verificamos de os lados formam um triângulo
if (lado1 + lado2 > lado3) and (lado2 + lado3 > lado1) and (lado1 + lado3 > lado2):
    print('Os valores podem formar um triângulo!')
    # comparamos os lados para verificar o tipo de triângulo
    if (lado1 == lado2) and (lado2 == lado3):
        print('O triângulo é equilátero.')
    elif (lado1 != lado2) and (lado2 != lado3) and (lado1 != lado3):
        print('O triângulo é escaleno.')
    else:
        print('O triângulo é isósceles.')
else:
    print('Os valores não podem formar um triângulo!')
# Out:
# Coletaremos os lados de um triângulo.
# Os valores podem formar um triângulo!
# O triângulo é isósceles.

# %%
#12) Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. 
# Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. 
# O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível 
# (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:

#O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
#O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.
# Coletamos a quantidade de litros e o tipo de combustível,
# já deixando o caractere em maiúsculo para facilitar nossa análise
quantidade_litros = float(input('Informe a quantidade de litros vendidos: '))
tipo_combustivel = input('Informe o tipo de combustível (E para etanol e D para diesel): ').upper()

#  Verificamos primeiro o tipo de combustível
if tipo_combustivel == 'E':
  # Taxamos o valor do preço em litros do etanol
  preco_litro = 1.70
  # De acordo com o valor da quantidade de litros, taxamos também o desconto
  if quantidade_litros <= 15:
    desconto = 0.02
  else:
    desconto = 0.04
elif tipo_combustivel == 'D':
  # Taxamos o valor do preço em litros do disel
  preco_litro = 2.00
  # De acordo com o valor da quantidade de litros, taxamos também o desconto
  if quantidade_litros <= 15:
    desconto = 0.03
  else:
    desconto = 0.05
# Caso ocorra um erro na especificação de tipo de combustível,
# consideramos entradas inválidas, e os preços são taxados em 0
else:
    print('Entradas inválidas!')
    preco_litro = 0
    desconto = 0

# Fazemos o cálculo do valor de desconto, seguido do cálculo do preço descontado
valor_desconto = preco_litro * quantidade_litros * desconto
valor_pago = preco_litro * quantidade_litros - valor_desconto

# Resultado
print(f'Valor a ser pago pelo cliente: R$ {valor_pago}')
# Out:
# Valor a ser pago pelo cliente: R$ 73.44

# %%
#13) Em uma empresa de venda de imóveis você precisa criar um código que analise os dados de vendas anuais para ajudar a diretoria na tomada de decisão. O código precisa coletar os dados de quantidade 
# de venda durante os anos de 2022 e 2023 e fazer um cálculo de variação percentual. A partir do valor da variação, deve ser enviada às seguintes sugestões:

#       Para variação acima de 20%: bonificação para o time de vendas.
#       Para variação entre 2% e 20%: pequena bonificação para time de vendas.
#       Para variação entre 2% e -10%: planejamento de políticas de incentivo às vendas.
#       Para bonificações abaixo de -10%: corte de gastos.

# Coletamos as vendas dos dois anos
venda_2022 = float(input('Informe a quantidade de vendas em 2022: '))
venda_2023 = float(input('Informe a quantidade de vendas em 2023: '))

# Calculamos a variação percentual entre as vendas dos anos de 2022 e 2023
var_percentual = 100 * (venda_2023 - venda_2022) / (venda_2022)

# Análise condicional da variação percentual para determinar a sugestão a ser enviada
if var_percentual > 20:
    print('Bonificação para o time de vendas.')
elif 2 <= var_percentual <= 20:
    print('Pequena bonificação para time de vendas.')
elif -10 <= var_percentual < 2:
    print('Planejamento de políticas de incentivo às vendas.')
else:
    print('Corte de gastos.')
# Out:
# Bonificação para o time de vendas.
